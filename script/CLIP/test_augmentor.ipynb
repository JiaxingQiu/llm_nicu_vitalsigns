# %%
import pandas as pd
from augmentor import  *

ts_hr = pd.read_excel('../..//data/PAS Challenge HR Data.xlsx', engine="calamine")
# Out:
# /Users/joyqiu/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Random seed set to 333

# %%
pretrained_model_path = './pretrained/hr_vae_linear_medium.pth' 
ts_df = ts_hr.iloc[0:10,2:]
augment_ts_df(ts_df, pretrained_model_path, K = 10)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 218.54it/s]
#     rowid    1    2    3    4    5    6    7    8    9  ...  292  293  294  \
# 0       0  133  133  134  134  134  134  134  134  134  ...  130  130  129
# 1       0  135  135  135  134  133  132  132  133  134  ...  129  128  127
# 2       0  132  133  133  133  133  132  132  133  133  ...  129  128  128
# 3       0  131  132  132  133  133  133  133  133  133  ...  129  129  128
# 4       0  133  133  133  132  131  131  132  133  134  ...  127  127  127
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 95      9  167  167  166  166  167  167  167  167  167  ...  171  171  171
# 96      9  168  167  167  167  167  167  167  167  167  ...  171  170  170
# 97      9  166  166  166  166  166  167  167  167  167  ...  171  171  171
# 98      9  167  167  167  167  166  167  167  167  167  ...  171  172  172
# 99      9  169  169  170  170  170  171  171  171  171  ...  169  169  170
#
# ...

# %%
ts_ds = ScaledTSDataset(ts_df)
x,_,_ = ts_ds[1]
plot_augmentor(x, pretrained_model_path)
